# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np

# %%
heart_diseases_data = pd.read_csv('C:/Users/DELL/Desktop/FODS/healthcare-dataset-stroke-data.csv')

# %%
heart_diseases_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
heart_diseases_data.fillna(heart_diseases_data.select_dtypes(include='number').mean(), inplace=True)

# %%
heart_diseases_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
heart_diseases_data.drop_duplicates(inplace = True)

# %%
heart_diseases_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
heart_diseases_data = pd.get_dummies(heart_diseases_data,columns=['gender'], drop_first=True)

# %%
heart_diseases_data
# Out:
#          id   age  hypertension  heart_disease ever_married      work_type  \
# 0      9046  67.0             0              1          Yes        Private
# 1     51676  61.0             0              0          Yes  Self-employed
# 2     31112  80.0             0              1          Yes        Private
# 3     60182  49.0             0              0          Yes        Private
# 4      1665  79.0             1              0          Yes  Self-employed
# ...     ...   ...           ...            ...          ...            ...
# 5105  18234  80.0             1              0          Yes        Private
# 5106  44873  81.0             0              0          Yes  Self-employed
# 5107  19723  35.0             0              0          Yes  Self-employed
# 5108  37544  51.0             0              0          Yes        Private
# 5109  44679  44.0             0              0          Yes       Govt_job
#
# ...

# %%
numerical_cols = ['age', 'avg_glucose_level', 'bmi']

# %%
scaler = StandardScaler()

# %%
heart_diseases_data[numerical_cols] = scaler.fit_transform(heart_diseases_data[numerical_cols])

# %%
heart_diseases_data
# Out:
#          id       age  hypertension  heart_disease ever_married  \
# 0      9046  1.051434             0              1          Yes
# 1     51676  0.786070             0              0          Yes
# 2     31112  1.626390             0              1          Yes
# 3     60182  0.255342             0              0          Yes
# 4      1665  1.582163             1              0          Yes
# ...     ...       ...           ...            ...          ...
# 5105  18234  1.626390             1              0          Yes
# 5106  44873  1.670617             0              0          Yes
# 5107  19723 -0.363842             0              0          Yes
# 5108  37544  0.343796             0              0          Yes
# 5109  44679  0.034205             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level           bmi  \
# 0           Private          Urban           2.706375  1.001234e+00
# ...
